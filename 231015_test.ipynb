# %%
import pandas as pd

from processing.data_pipeline import pipeline
from processing.data_processing import *

# %%
data_path = "/Users/nicolas/Workspace/School/V2023/Big Data/Exercise 3/tdt4225_assignment3/dataset"

# %%
users, activities, track_points = pipeline(data_path)
# Out:
# Skipping /Users/nicolas/Workspace/School/V2023/Big Data/Exercise 3/tdt4225_assignment3/dataset/Data/000/Trajectory/20090528012338.plt - File is too long
# Skipping /Users/nicolas/Workspace/School/V2023/Big Data/Exercise 3/tdt4225_assignment3/dataset/Data/000/Trajectory/20090429005954.plt - File is too long
# Skipping /Users/nicolas/Workspace/School/V2023/Big Data/Exercise 3/tdt4225_assignment3/dataset/Data/000/Trajectory/20090419005226.plt - File is too long
# Skipping /Users/nicolas/Workspace/School/V2023/Big Data/Exercise 3/tdt4225_assignment3/dataset/Data/000/Trajectory/20090413213935.plt - File is too long
# Skipping /Users/nicolas/Workspace/School/V2023/Big Data/Exercise 3/tdt4225_assignment3/dataset/Data/000/Trajectory/20090501035138.plt - File is too long
# Skipping /Users/nicolas/Workspace/School/V2023/Big Data/Exercise 3/tdt4225_assignment3/dataset/Data/000/Trajectory/20090430032332.plt - File is too long
# ...

# %%
import pickle

with open('data/users.pkl', 'wb') as fp:
    pickle.dump(users, fp)
    print('dictionary saved successfully to file')

with open('data/activities.pkl', 'wb') as fp:
    pickle.dump(activities, fp)
    print('dictionary saved successfully to file')

with open('data/track_points.pkl', 'wb') as fp:
    pickle.dump(track_points, fp)
    print('dictionary saved successfully to file')

# %%
with open('data/users.pkl', 'rb') as fp:
    _users = pickle.load(fp)
    print('dictionary loaded successfully from file')
_users

# %%
with open('data/activities.pkl', 'rb') as fp:
    _activities = pickle.load(fp)
    print('dictionary loaded successfully from file')
_activities

# %%
with open('data/track_points.pkl', 'rb') as fp:
    _track_points = pickle.load(fp)
    print('dictionary loaded successfully from file')
_track_points
